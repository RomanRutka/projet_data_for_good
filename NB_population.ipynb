# %%
import pandas as pd
import numpy as np
# utm
# pip install utm
import utm
import re
from glob import glob

pd.options.mode.chained_assignment = None

# %%
data = pd.read_csv('/home/jerome.dutroncy@Digital-Grenoble.local/Documents/Projet_cars/data_pop/donnees_communes.csv', delimiter=';')
data
# Out:
#        CODREG                   REG CODDEP  CODARR  CODCAN  CODCOM  \
# 0          84  Auvergne-Rhône-Alpes     01       2     8.0       1
# 1          84  Auvergne-Rhône-Alpes     01       1     1.0       2
# 2          84  Auvergne-Rhône-Alpes     01       1     1.0       4
# 3          84  Auvergne-Rhône-Alpes     01       2    22.0       5
# 4          84  Auvergne-Rhône-Alpes     01       1     4.0       6
# ...       ...                   ...    ...     ...     ...     ...
# 34975       4            La Réunion    974       1     4.0     420
# 34976       4            La Réunion    974       3     6.0     421
# 34977       4            La Réunion    974       2    99.0     422
# 34978       4            La Réunion    974       4    14.0     423
# 34979       4            La Réunion    974       2    16.0     424
#
#                            COM   PMUN  PCAP   PTOT
# 0      L'Abergement-Clémenciat    806    15    821
# 1        L'Abergement-de-Varey    262     6    268
# ...
